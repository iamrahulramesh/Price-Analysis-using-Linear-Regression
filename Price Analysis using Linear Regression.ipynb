# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\Ramesh\Desktop\datasets\Melbourne_housing_FULL.csv')
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
len(df['Date'].unique())/4
# Out:
# 19.5

# %%
var = df[df['Type'] =='h'].sort_values(['Date'],ascending = False).groupby('Date').std()
var
# Out:
#                Rooms          Price  Distance    Postcode  Bedroom2  Bathroom  \
# Date
# 1/07/2017   0.886185  608448.567389  8.596348  184.039713  0.911332  0.729390
# 10/02/2018  0.776831  353735.169447  8.138740  209.218766  0.771200  0.654152
# 10/03/2018  0.747891  398592.105251  7.716418  185.046700  0.738481  0.738802
# 10/09/2016  1.052055  671959.681570  3.239501   58.457404  1.014310  0.912795
# 10/12/2016  0.893316  762956.460291  3.460290   59.414043  0.890380  0.772513
# ...              ...            ...       ...         ...       ...       ...
# 8/04/2017   0.776107  641119.278002  3.482439   60.161143  0.791885  0.641744
# 8/07/2017   0.815346  432334.090291  7.856021  169.107973  0.798974  0.836505
# 8/10/2016   0.807257  538781.726792  3.357505   57.079196  2.069088  1.051548
# 9/09/2017   0.803633  640415.023289  7.640974  134.783942  0.807353  0.719284
# 9/12/2017   0.798307  680536.894598  8.104599  153.956373  0.801797  0.763768
#
# ...

# %%
count = df[df['Type'] =='h'].sort_values('Date',ascending = False).groupby('Date').count()
count
# Out:
#             Suburb  Address  Rooms  Type  Price  Method  SellerG  Distance  \
# Date
# 1/07/2017      339      339    339   339    265     339      339       339
# 10/02/2018     220      220    220   220    180     220      220       220
# 10/03/2018     122      122    122   122     84     122      122       122
# 10/09/2016     246      246    246   246    181     246      246       246
# 10/12/2016     353      353    353   353    267     353      353       353
# ...            ...      ...    ...   ...    ...     ...      ...       ...
# 8/04/2017      269      269    269   269    208     269      269       269
# 8/07/2017      290      290    290   290    234     290      290       290
# 8/10/2016      252      252    252   252    204     252      252       252
# 9/09/2017      434      434    434   434    323     434      434       434
# 9/12/2017      681      681    681   681    520     681      681       681
#
# ...

# %%
mean =df[df['Type']=='h'].sort_values('Date',ascending =False).groupby('Date').mean()
mean
# Out:
#                Rooms         Price   Distance     Postcode  Bedroom2  \
# Date
# 1/07/2017   3.401180  1.023303e+06  15.331563  3147.050147  3.420233
# 10/02/2018  3.386364  8.815972e+05  16.599091  3156.100000  3.365000
# 10/03/2018  3.581967  8.535876e+05  16.341803  3147.180328  3.601770
# 10/09/2016  3.536585  1.395397e+06   9.132520  3104.333333  3.315271
# 10/12/2016  3.192635  1.336055e+06   9.005666  3094.609065  3.180602
# ...              ...           ...        ...          ...       ...
# 8/04/2017   3.115242  1.231043e+06   8.933457  3083.189591  3.098214
# 8/07/2017   3.351724  9.368024e+05  15.692069  3135.827586  3.344322
# 8/10/2016   3.146825  1.120159e+06   8.868651  3084.702381  3.145631
# 9/09/2017   3.357143  1.205070e+06  13.109677  3135.292627  3.347932
# 9/12/2017   3.399413  1.127682e+06  14.112335  3135.355360  3.409677
#
#             Bathroom       Car    Landsize  BuildingArea    YearBuilt  \
# Date
# ...

# %%
mean['Price'].plot(yerr = var['Price'],ylim =(400000,1500000) )
degrees = 70
plt.xticks(rotation=degrees)
plt.show()

# %%
means = df[(df['Type']=='h') & (df['Distance'] < 13)].sort_values('Date',ascending = False).groupby('Date').mean()
means
# Out:
#                Rooms         Price  Distance     Postcode  Bedroom2  Bathroom  \
# Date
# 1/07/2017   3.234043  1.313958e+06  7.858156  3080.680851  3.203540  1.557522
# 10/02/2018  3.102941  1.160296e+06  7.866176  3068.073529  3.047619  1.444444
# 10/03/2018  3.225000  1.125803e+06  9.012500  3077.925000  3.285714  1.457143
# 10/09/2016  3.443902  1.418583e+06  8.214146  3098.975610  3.211765  1.788235
# 10/12/2016  3.185811  1.410519e+06  8.105405  3092.483108  3.164062  1.613281
# ...              ...           ...       ...          ...       ...       ...
# 8/04/2017   3.075893  1.280722e+06  7.947321  3081.187500  3.052356  1.513089
# 8/07/2017   3.159292  1.118452e+06  8.520354  3071.530973  3.177570  1.542056
# 8/10/2016   3.136150  1.166219e+06  7.964319  3079.882629  3.154286  1.594286
# 9/09/2017   3.179487  1.431261e+06  7.518803  3097.743590  3.167421  1.647059
# 9/12/2017   3.265672  1.410276e+06  7.815224  3091.722388  3.280936  1.715719
#
# ...

# %%
errors = df[(df['Type']=='h') & (df['Distance'] <13)].sort_values('Date',ascending = False).groupby('Date').std()
errors
# Out:
#                Rooms          Price  Distance   Postcode  Bedroom2  Bathroom  \
# Date
# 1/07/2017   0.907416  715114.358126  3.064757  49.365448  0.907895  0.731169
# 10/02/2018  0.848875  348858.793385  3.388110  51.243148  0.831411  0.616383
# 10/03/2018  0.659740  526075.051623  2.873324  42.986812  0.667367  0.657216
# 10/09/2016  0.925152  671222.945047  2.727950  55.891127  0.955756  0.904873
# 10/12/2016  0.936601  801756.750911  3.030317  57.548974  0.926959  0.798810
# ...              ...            ...       ...        ...       ...       ...
# 8/04/2017   0.774336  667456.806997  2.945696  59.375076  0.792984  0.655813
# 8/07/2017   0.950248  487356.428271  3.105875  50.999137  0.949807  0.914045
# 8/10/2016   0.855205  562364.783886  2.821906  54.160665  2.216493  1.109505
# 9/09/2017   0.808914  699699.123005  3.083291  57.774484  0.805677  0.764171
# 9/12/2017   0.877795  784530.882622  3.007223  55.646047  0.898174  0.825020
#
# ...

# %%
means.columns
# Out:
# Index(['Rooms', 'Price', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
#        'Propertycount'],
#       dtype='object')

# %%
means.drop(['Price','Postcode','Longtitude','Lattitude','Distance','BuildingArea','Propertycount','Landsize','YearBuilt'],axis =1).plot(yerr = errors)
degrees = 70
plt.xticks(rotation=degrees)
plt.show()

# %%
df[df['Type']=='h'].sort_values('Date',ascending = False ).groupby('Date').mean()
# Out:
#                Rooms         Price   Distance     Postcode  Bedroom2  \
# Date
# 1/07/2017   3.401180  1.023303e+06  15.331563  3147.050147  3.420233
# 10/02/2018  3.386364  8.815972e+05  16.599091  3156.100000  3.365000
# 10/03/2018  3.581967  8.535876e+05  16.341803  3147.180328  3.601770
# 10/09/2016  3.536585  1.395397e+06   9.132520  3104.333333  3.315271
# 10/12/2016  3.192635  1.336055e+06   9.005666  3094.609065  3.180602
# ...              ...           ...        ...          ...       ...
# 8/04/2017   3.115242  1.231043e+06   8.933457  3083.189591  3.098214
# 8/07/2017   3.351724  9.368024e+05  15.692069  3135.827586  3.344322
# 8/10/2016   3.146825  1.120159e+06   8.868651  3084.702381  3.145631
# 9/09/2017   3.357143  1.205070e+06  13.109677  3135.292627  3.347932
# 9/12/2017   3.399413  1.127682e+06  14.112335  3135.355360  3.409677
#
#             Bathroom       Car    Landsize  BuildingArea    YearBuilt  \
# Date
# ...

# %%
pd.set_eng_float_format(accuracy =1,use_eng_prefix = True)
#Use the set_eng_float_format function to alter the floating-point formatting of pandas objects to produce a particular format.
df[(df['Type'] =='h') & (df['Distance']<14)  & (df['Distance']>13.7)].sort_values('Date',ascending= False ).groupby(['Suburb','SellerG']).mean()
# Out:
#                     Rooms   Price  Distance  Postcode  Bedroom2  Bathroom  \
# Suburb   SellerG
# Albion   Barry        2.3  651.6k      13.9      3.0k       2.3       1.0
#          Bells        3.0  784.2k      13.9      3.0k       3.2       1.2
#          Douglas      3.3  658.3k      13.9      3.0k       3.5       1.0
#          FN           3.0  625.0k      13.9      3.0k       3.0       1.0
#          Sweeney      3.0  637.7k      13.9      3.0k       3.0       1.3
# ...                   ...     ...       ...       ...       ...       ...
# Viewbank Fletchers    3.8    1.0M      13.8      3.1k       3.5       1.5
#          Miles        3.8  963.1k      13.8      3.1k       3.8       2.1
#          Morrison     3.0  820.0k      13.8      3.1k       3.0       2.0
#          Nelson       3.8  931.0k      13.8      3.1k       4.0       2.0
#          Ray          3.0  765.0k      13.8      3.1k       3.0       1.0
#
# ...

# %%
sns.kdeplot(df[(df['Suburb'] == 'Doncaster') & (df['Type'] == 'u') & (df['Rooms']== 2)]['Price'])

# %%
sns.kdeplot(df[(df['Suburb']=='Northcote') & (df['Type']== 'u') & (df['Rooms'] ==2)]['Price'])

# %%
plt.figure(figsize = (20,15))

my_axis = sns.kdeplot(df['Price'][((df['Type'] =='u') & (df['Distance'] > 8) & (df['Distance']<10) & (df['Rooms'] > 2))])
my_axis.axis(xmin = 0, xmax = 2000000)
# Out:
# (0, 2000000, 0.0, 2.0258804585386846e-06)

# %%
sns.lmplot("Distance","Price",df[(df['Rooms']<=5) & (df['Rooms'] >2) & (df['Type'] =='h') & (df['Price'] < 1000000)].dropna(),
           hue ='Rooms',size = 10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize = (10,15))
df[(df['Rooms']>2) & (df['Type'] =='h') & (df['Landsize'] <5000)] [['Distance','Landsize']].dropna().groupby('Distance').mean().plot()

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
fig,ax = plt.subplots(figsize = (15,15))
sns.heatmap(df[df['Type'] =='h'].corr(),annot = True,cmap="YlGnBu")

# %%
df_dr = df.dropna().sort_values("Date")
df_dr
# Out:
#              Suburb           Address  Rooms Type   Price Method  \
# 14499       Mitcham      29 Fuller St      3    h  950.0k      S
# 14232  Altona North   151 Chambers Rd      3    h  900.0k      S
# 14480     Maidstone  3/83 Mitchell St      3    t  895.0k      S
# 14478     Maidstone   14/4 Crefden St      1    u  280.0k     VB
# 14471         Lalor    11 Benaroon Dr      4    h  750.0k      S
# ...             ...               ...    ...  ...     ...    ...
# 30324        Epping     1 Koukoura Dr      4    h  585.0k     PI
# 30323        Epping    5 Gillespie Pl      3    h  619.0k      S
# 30302   Elsternwick   49 Trevelyan St      3    h    1.5M     VB
# 30886      Werribee      12 Garden Ct      4    h  620.0k     SP
# 30780  South Morang       15 Payne Pl      4    h  621.0k      S
#
#              SellerG       Date  Distance  Postcode  ...  Bathroom  Car  \
# 14499           Noel  1/07/2017      17.2      3.1k  ...       1.0  2.0
# ...

# %%
all_data = []

# %%
from datetime import date

df_dr['Date'] = pd.to_datetime(df_dr['Date']) #unless you convert it into date , it keeps throwing error
date_diff = [x - df_dr['Date'].min() for x in df_dr['Date']]
pd.DataFrame(date_diff)
# Out:
#             0
# 0    304 days
# 1    304 days
# 2    304 days
# 3    304 days
# 4    304 days
# ...       ...
# 8882 552 days
# 8883 552 days
# 8884 552 days
# 8885 552 days
# 8886 552 days
#
# [8887 rows x 1 columns]

# %%
df_dr['Date'] =date_diff

# %%
suburb_dummies = pd.get_dummies(df_dr[['Type','Method']])

# %%
all_data = df_dr.drop(["Address","Price","Date", "SellerG","Suburb","Type","Method","CouncilArea","Regionname"],
                      axis =1).join(suburb_dummies)

# %%
all_data
# Out:
#        Rooms  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 14499      3      17.2      3.1k       3.0       1.0  2.0     608.0
# 14232      3       9.4      3.0k       3.0       1.0  2.0     672.0
# 14480      3       6.4      3.0k       3.0       2.0  2.0     262.0
# 14478      1       6.4      3.0k       1.0       1.0  1.0      3.8k
# 14471      4      16.3      3.1k       4.0       2.0  4.0     544.0
# ...      ...       ...       ...       ...       ...  ...       ...
# 30324      4      19.6      3.1k       4.0       2.0  2.0     396.0
# 30323      3      19.6      3.1k       3.0       1.0  2.0     124.0
# 30302      3       7.2      3.2k       2.0       1.0  1.0     381.0
# 30886      4      14.7      3.0k       4.0       2.0  2.0     630.0
# 30780      4      20.5      3.8k       4.0       2.0  2.0     568.0
#
#        BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount  Type_h  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
lr = LinearRegression()

# %%
X = all_data
y =df_dr['Price']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lr.intercept_)
# Out:
# -137141729.90603912

# %%
X.columns
# Out:
# Index(['Rooms', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
#        'Propertycount', 'Type_h', 'Type_t', 'Type_u', 'Method_PI', 'Method_S',
#        'Method_SA', 'Method_SP', 'Method_VB'],
#       dtype='object')

# %%
coef_df = pd.DataFrame(lr.coef_,X.columns,columns =['Coefficient'])
ranked_suburbs = coef_df.sort_values('Coefficient',ascending = False)

# %%
coef_df
# Out:
#                Coefficient
# Rooms               119.2k
# Distance            -45.2k
# Postcode             849.7
# Bedroom2              1.5k
# Bathroom            200.6k
# Car                  59.6k
# Landsize              33.4
# BuildingArea          1.8k
# YearBuilt            -3.4k
# Lattitude            -1.3M
# Longtitude          629.4k
# Propertycount      -330.1m
# Type_h              162.0k
# Type_t               -1.2k
# Type_u             -160.8k
# Method_PI           -21.3k
# Method_S             30.5k
# Method_SA           -17.5k
# Method_SP           -30.2k
# Method_VB            38.5k

# %%
ranked_suburbs
# Out:
#                Coefficient
# Longtitude          629.4k
# Bathroom            200.6k
# Type_h              162.0k
# Rooms               119.2k
# Car                  59.6k
# Method_VB            38.5k
# Method_S             30.5k
# BuildingArea          1.8k
# Bedroom2              1.5k
# Postcode             849.7
# Landsize              33.4
# Propertycount      -330.1m
# Type_t               -1.2k
# YearBuilt            -3.4k
# Method_SA           -17.5k
# Method_PI           -21.3k
# Method_SP           -30.2k
# Distance            -45.2k
# Type_u             -160.8k
# Lattitude            -1.3M

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([ 513229.13067564, 1066786.8239871 , 1696428.51364854, ...,
#        -846603.07578731,  703595.23712787,  785549.91928628])

# %%
plt.scatter(y_test,y_pred)
plt.ylim([200000,1000000])
plt.xlim([200000,1000000])
# Out:
# (200000, 1000000)

# %%
fig,ax = plt.subplots(figsize = (15,15))
sns.distplot(y_test-y_pred,bins = 50)

# %%
from sklearn import metrics

# %%
print('Mean Absolute Error : ',round(metrics.mean_absolute_error(y_test,y_pred)))
print('Mean Squared Error: ',round(metrics.mean_squared_error(y_test,y_pred)))
print("Root Mean Squared Error: ",round(np.sqrt(metrics.mean_squared_error(y_test,y_pred))))
# Out:
# Mean Absolute Error :  262661.0
# Mean Squared Error:  151405911492.0
# Root Mean Squared Error:  389109.0
